# %%
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
import requests
from bs4 import BeautifulSoup
import json
import math
import sqlite3
import time
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.common.action_chains import ActionChains

citys = ["Los Angeles","Miami","Orlando","Las Vegas"]
for city in citys:


    driver = webdriver.Chrome()
    driver.get('https://www.booking.com')
    #city = "New York"
    driver.find_element_by_id('ss').send_keys(city)

    driver.find_element_by_class_name("sb-searchbox__button").click()

    WebDriverWait(driver, 10).until(lambda d: d.execute_script('return document.readyState') == 'complete')

    headers = {
        "User-Agent":
        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
        }



    s = requests.session()
    s.headers.update(headers)
    #pass cookie to requests
    for cookie in driver.get_cookies():
        c = {cookie['name']: cookie['value']}
        s.cookies.update(c)
    


    html = driver.page_source
    #print(html)

    soup=BeautifulSoup(html,'html.parser')


    def getnum(soup): 
        indexconta = []
        pagenum = soup.find_all('li',class_='bui-pagination__item sr_pagination_item')
        maxnum = int(2);
        for num in pagenum:       #find page number
            index = num.find('div',class_='bui-u-inline')
            index = index.get_text()
            index = int(index)
            indexconta.append(index)
        if max(indexconta) < maxnum:
            return(max(indexconta))
        else:
            return(maxnum);
    pagenumber = getnum(soup)
    #conn = sqlite3.connect('booking.db')


#html1 = html
#driver1 = driver
    counter = int(1)
    for i in range(getnum(soup)):
    
        soup1=BeautifulSoup(html,'html.parser')
        print(soup1.title)
        print(i)  
        
        for link in soup1.find_all("div", class_="sr_item_main_block"):
                link2 = link.find('a',class_='hotel_name_link url')
              #  print(link.get('href'))
              # search for hotelwebsite and get value from header
                str1 = 'https://www.booking.com'
                str2 = link2.get('href')
                #str2 = str2[2:]
                str2 = str2.replace("\r","")
                str2 = str2.replace("\n","")
                #url1 = str1 +'/' +str2
                url1 = str1 + str2
                #print (url1)
                response =requests.get(url1)
                #print(response.status_code)
                page = response.text
                #print (page)
                soup2=BeautifulSoup(page,'html.parser')
                #a = soup2.find("streetAddress")
                #print (soup2.prettify())
                #a = soup2.find('scr', class_ ="bui-review-score__badge")
           
                data = json.loads(soup2.find('script', type='application/ld+json').text)
                try:
                    name =str(data['name'])
                   # print(name)
                    
                except:
                    name='na'
               
                try:
                    region = str(data['address']['addressRegion'])
                    
                except:
                    region='na'
                    
                try:
                    country = str(data['address']['addressCountry'])
                    
                except:
                    country='na'
                    
                try:
                    address = str(data['address']['streetAddress'])
                    
                except:
                    address='na'
                    
                try:
                    description = str(data['description'])
                    
                except:
                    description='na'
                    
                try:
                    pricerange = str(data['priceRange'])
                    
                except:
                    pricerange='na'
                try:
                    rating = int(data['aggregateRating']['ratingValue'])
                        
                except:
                    rating='na'
                counter = counter +1 
                
                for room in soup2.find_all("div", id =  'roomtable') 
                    

                file1 = open(city+".txt","a")
                file1.write("index" + str(counter) +'\n')
                file1.write("name: "+ name+ '\n')
                file1.write("region: " + region + '\n')
                file1.write("country: " + country + '\n')
                file1.write("address: "+ address+ '\n')
                file1.write("description: " + description + '\n')
                file1.write("pricerange: " + pricerange + '\n')
                file1.write("rating: " + str(rating) + '\n')
                file1.write('\n')
            
                file1.close()
               
                
                print(name + ' done')
                time.sleep(2)
            
        driver1 = driver.find_element_by_css_selector("li[class='bui-pagination__item bui-pagination__next-arrow']")
        driver1.find_element_by_css_selector("a[class^='bui']").click()
        time.sleep(4)
#    print(driver.current_url)
        html = driver.page_source
    
 #   WebDriverWait(driver, 10).until(lambda d: d.execute_script('return document.readyState') == 'complete')
 #   print(driver.current_url)
 #   driver.switch_to_window(driver.window_handles[-1])
  #  driver.implicitly_wait(20)
  #  print(driver.current_url)
# Out:
# <title>Booking.com: Hotels in Los Angeles. Book your hotel now!</title>
# 0
# Four Points by Sheraton Los Angeles International Airport done
# Rooms in Hollywood Hills Mansion w/ Gorgeous Views done
# Abbot Kinney Apartment done
# Venice Breeze Suites done
# Arizona done
# Walk of Fame Hostel done
# Oakwood Toluca Hills done
# HOLLYWOOD LA LUXURY done
# The Big Bungalow done
# Comforting Hollywood Getaway done
# Hollywood Sunsets II done
# Cloverfield Apartments near Pier done
# LEVEL DTLA done
# Solo Motel Broadway done
# Waterfront Penthouse at Marina Del Rey done
# <title>Booking.com: Hotels in Los Angeles. Book your hotel now!</title>
# 1
# Service Apartments in Business District and LA Beach Area done
# Executive Apartments in Westwood LA done
# Luxury, Hollywood Walk of Fame done
# Friendship Motor Inn done
# Hollywood Luxury Suite * 5 beds + Parking done
# Hollywood LUXE done
# Modern 3 Bedroom 2 Bath Newly Remodeled Building. done
# SkyStar Apartments done
# Westwood Ultimate Luxury done
# Downtown Oasis done
# Corporate Rentals Opposite Staples Center done
# Gorgeous 2 Bedroom Apartments in DTLA done
# Seabreeze Penthouse Style with Astonishing View done
# Hollywood Clean And Safe Suite done
# Hollywood Inn Express North done
# <title>Booking.com: Hotels in Miami Beach. Book your hotel now!</title>
# 0
# Catalina Hotel & Beach Club done
# Royal Palm South Beach Miami, a Tribute Portfolio Resort done
# Viscay Hotel done
# Freehand Miami done
# Loews Miami Beach Hotel done
# Ocean & Bayfront Apartment in Miami Beach done
# Acqua Bay Luxury Apartments done
# FBH Fashion Boutique Hotel done
# Generator Miami done
# Dream South Beach done
# Hotel La Flora done
# El Paseo Hotel done
# 751 Meridian House done
# Sogno di Mare by Miami Beach done
# Avalon Hotel done
# <title>Booking.com: Hotels in Miami Beach. Book your hotel now!</title>
# 1
# The Fountain Vacation Rentals done
# Nautilus by Arlo done
# Tradewinds Apartment Hotel Miami Beach done
# Courtyard Two-Bedroom Apartments by Royal Stays done
# RIU Plaza Miami Beach done
# Room Mate Waldorf Towers done
# Albion Hotel done
# SBV Luxury Ocean Hotel Suites done
# Best Western On The Bay Inn & Marina done
# Ocean Reef Suites done
# Casa Grande Suites on Ocean Drive done
# Seacoast Suites on Miami Beach done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ff734346734e> in <module>
#     153
#     154                 print(name + ' done')
# --> 155                 time.sleep(2)
#     156
#     157         driver1 = driver.find_element_by_css_selector("li[class='bui-pagination__item bui-pagination__next-arrow']")
#
# KeyboardInterrupt:
