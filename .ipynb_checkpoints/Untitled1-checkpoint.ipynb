# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.booking.com/hotel/hk/y-loft.zh-cn.html'

# %%
headers={'user-agent':'Mozilla/5.0'}
r=requests.get(url,headers=headers)

def get_page(url):
    headers={'user-agent':'Mozilla/5.0'}
    try:
        r=requests.get(url,headers=headers)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return r.text
    except Exception as e:
        print(e)
html=get_page(url)
soup=BeautifulSoup(html,'html.parser')
div=soup.find('div',{'class':{'bodyconstraint-inner'}})

info=div.find('div',{'class':{'bui-review-score__badge'}})

desc=info.text.strip()


print(desc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-dfe4d60c1274> in <module>
#       6 div=soup.find('div',{'class':{'bodyconstraint-inner'}})
#       7
# ----> 8 info=div.find('div',{'class':{'bui-review-score__badge'}})
#       9
#      10 desc=info.text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
def get_page(url):
    headers={'user-agent':'Mozilla/5.0'}
    try:
        r=requests.get(url,headers=headers)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return r.text
    except Exception as e:
        print(e)
        
        
def get_info(url):
    html=get_page(url)
    soup=BeautifulSoup(html,'html.parser')
    divs=soup.find_all('div',{'class':{'hotellist_inner'}})
    for div in divs:
        info1=div.find('span',{'class':{'sr-hotel__name'}})
        name=info1.text.strip()  #店名
        try:
            info2=div.find('span',{'class':{'china_stars_categories_title'}})
            style=info2.text.strip()  #类型
        except:
            style='未知'
        level=div['data-class']  #等级
        score=div['data-score']  #得分
        if score=='':
            score='未知'
        info3=div.find('div',{'class':{'address'}})
        address=info3.text.strip().replace('\n','')  #地址
        info4=div.find('div',{'class':{'hotel_desc'}})
        desc=info4.text.strip()  #简介
        with open('Booking_南京.txt','a+',encoding='utf8')as f:
            f.write('店名：'+name+'\n')
            f.write('类型：'+style+'\n')
            f.write('等级：'+level+'\n')
            f.write('得分：'+score+'\n')
            f.write('地址：'+address+'\n')
            f.write('简介：'+desc+'\n')
            f.write('\n')
        f.close()
        print('{}-----(*￣︶￣)'.format(name))
        
url = 'https://www.booking.com/searchresults.html&city=-1353149'

get_info(url)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.booking.com/hotel/hk/y-loft.zh-cn.html'

def get_page(url):
    headers={'user-agent':'Mozilla/5.0'}
    try:
        r=requests.get(url,headers=headers)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return r.text
    except Exception as e:
        print(e)

#def get_num(url):
   # html=get_page(url)
    #soup=BeautifulSoup(html,'html.parser')
    #ul=soup.find_all('ul',{'class':{'bui-pagination__list'}})[-1]
   # num=ul('li')[-1].text.strip()
   # return int(num)  #32

def get_info(url):
    html=get_page(url)
    soup=BeautifulSoup(html,'html.parser')
    divs=soup.find_all('div',{'class':{'sr_item_default'}})
    for div in divs:
        info1=div.find('span',{'class':{'sr-hotel__name'}})
        name=info1.text.strip()  #店名
        try:
            info2=div.find('span',{'class':{'china_stars_categories_title'}})
            style=info2.text.strip()  #类型
        except:
            style='未知'
        level=div['data-class']  #等级
        score=div['data-score']  #得分
        if score=='':
            score='未知'
        info3=div.find('div',{'class':{'address'}})
        address=info3.text.strip().replace('\n','')  #地址
        info4=div.find('div',{'class':{'hotel_desc'}})
        desc=info4.text.strip()  #简介
        with open('Booking_南京.txt','a+',encoding='utf8')as f:
            f.write('店名：'+name+'\n')
            f.write('类型：'+style+'\n')
            f.write('等级：'+level+'\n')
            f.write('得分：'+score+'\n')
            f.write('地址：'+address+'\n')
            f.write('简介：'+desc+'\n')
            f.write('\n')
        f.close()
        print('{}-----(*￣︶￣)'.format(name))

#if __name__ == '__main__':
 #   start_url='https://www.booking.com/searchresults.html?city=-1353149'
 #   num=get_num(start_url)
  #  print(num);
   # for i in range(num -1 ):
     #   page_url=start_url+'&offset='+str(i*40)
     #   get_info(page_url)
