# %%
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
import requests
from bs4 import BeautifulSoup
import json
import math
import sqlite3
import time
from selenium.webdriver.support import expected_conditions as EC
import random

from selenium.webdriver.common.action_chains import ActionChains

citys = ["Kyoto" ,"Bangkok","Toronto","Vancouver"] #,"Miami","Sydney","Munich","Tokyo","Berlin","Moscow","Vienna","Orlando","Las Vegas""Shanghai","Venice","Rome","Florence","Paris", "Barcelona","Manchester","London","Edinburgh",
for city in citys:


    driver = webdriver.Chrome()
    driver.get('https://www.booking.com')
    #city = "New York"
    driver.find_element_by_id('ss').send_keys(city)

    driver.find_element_by_class_name("sb-searchbox__button").click()

    WebDriverWait(driver, 10).until(lambda d: d.execute_script('return document.readyState') == 'complete')

    headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
    }


    s = requests.session()
    s.headers.update(headers)
    #pass cookie to requests
    for cookie in driver.get_cookies():
        c = {cookie['name']: cookie['value']}
        s.cookies.update(c)
    


    html = driver.page_source
    #print(html)

    soup=BeautifulSoup(html,'html.parser')


    def getnum(soup): 
        indexconta = []
        pagenum = soup.find_all('li',class_='bui-pagination__item sr_pagination_item')
        maxnum = int(3);
        for num in pagenum:       #find page number
            index = num.find('div',class_='bui-u-inline')
            index = index.get_text()
            index = int(index)
            indexconta.append(index)
        if max(indexconta) < maxnum:
            return(max(indexconta))
        else:
            return(maxnum);
    pagenumber = getnum(soup)
    #conn = sqlite3.connect('booking.db')


#html1 = html
#driver1 = driver
    counter = int(1)
    for i in range(getnum(soup)):
    
        soup1=BeautifulSoup(html,'html.parser')
        print(soup1.title)
        print(i)  
        
        for link in soup1.find_all("div", class_="sr_item_main_block"):
                link2 = link.find('a',class_='hotel_name_link url')
              #  print(link.get('href'))
              # search for hotelwebsite and get value from header
                str1 = 'https://www.booking.com'
                str2 = link2.get('href')
                #str2 = str2[2:]
                str2 = str2.replace("\r","")
                str2 = str2.replace("\n","")
                #url1 = str1 +'/' +str2
                url1 = str1 + str2
                #print (url1)
                response =requests.get(url1)
                #print(response.status_code)
                page = response.text
                #print (page)
                soup2=BeautifulSoup(page,'html.parser')
                #a = soup2.find("streetAddress")
                #print (soup2.prettify())
                #a = soup2.find('scr', class_ ="bui-review-score__badge")
                
                data = json.loads(soup2.find('script', type='application/ld+json').text)
                try:
                    name =str(data['name'])
                   # print(name)
                    
                except:
                    name='na'
                
                try:
                    region = str(data['address']['addressRegion'])
                    
                except:
                    region='na'
                    
                try:
                    country = str(data['address']['addressCountry'])
                    
                except:
                    country='na'
                    
                try:
                    address = str(data['address']['streetAddress'])
                    
                except:
                    address='na'
                    
                try:
                    description = str(data['description'])
                    
                except:
                    description='na'
                    
                try:
                    pricerange = str(data['priceRange'])
                    
                except:
                    pricerange='na'
                try:
                    rating = float(data['aggregateRating']['ratingValue'])
                        
                except:
                    rating='na'
                    
                counter = counter +1 
               
                    
                
                file1 = open("13_" + city+" booking "+".txt","a")
                file1.write("index " + str(counter) +'\n')
                try:
                    file1.write("name: "+ name+ '\n')
                except:
                    file1.write("name: "+ "na"+ '\n')
                try:
                    file1.write("region: " + region + '\n')
                except:
                    file1.write("region: " + "na" + '\n')
                try:
                    file1.write("country: " + country + '\n')
                except:
                    file1.write("country: " + "na" + '\n')
                try:
                    file1.write("address: "+ address+ '\n')
                except:
                    file1.write("address: "+ "na"+ '\n')
                try:
                    file1.write("description: " + description + '\n')
                except:
                    file1.write("description: " + "na" + '\n')
                try:
                    file1.write("pricerange: " + pricerange + '\n')
                except:
                    file1.write("pricerange: " + "na" + '\n') 
                file1.write("rating: " + str(rating) + '\n')
                file1.write("roomtype:"+'\n')
                
                
                roomidx = int(1)
               # for roomtype in soup2.find("div", id = 'roomtable'):_
                roomtype = soup2.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']=="maxotel_rooms")
                try:
                    roomtype = roomtype.find('tbody')
                    for room in roomtype.find_all(lambda tag: tag.name=='tr'):
                        #print (room)
                        if len(room.find_all('i',class_ = 'bicon bicon-occupancy')) != 0:
                            capacity = len(room.find_all('i',class_ = 'bicon bicon-occupancy'))
                            #print (capacity)
                            file1.write("roomcapacity: " + str(capacity) +'\n')
                            roomname = room.find("a", class_ ='jqrt togglelink')
                            try:
                                roomname =  roomname.text.strip()
                                file1.write("roomname: " + roomname +'\n')
                            except:
                                file1.write("roomname: " + "na" +'\n')
                            
                            bed = room.find("li",class_ = 'rt-bed-type')
                            try:
                                #print (bed.getText())
                                bed = bed.text.strip()
                                file1.write("bed type: " + bed +'\n')
                            except:
                                file1.write("bed type: " + "no bed type" + "\n")
                except:
                    file1.write("roomtype: "+ "na")
                file1.write('\n')
                file1.close()
               
                time.sleep(4)
                print(name + ' done')
                
            
        driver1 = driver.find_element_by_css_selector("li[class='bui-pagination__item bui-pagination__next-arrow']")
        driver1.find_element_by_css_selector("a[class^='bui']").click()
        time.sleep(8)
#    print(driver.current_url)
        html = driver.page_source
    
 #   WebDriverWait(driver, 10).until(lambda d: d.execute_script('return document.readyState') == 'complete')
 #   print(driver.current_url)
 #   driver.switch_to_window(driver.window_handles[-1])
  #  driver.implicitly_wait(20)
  #  print(driver.current_url)
# Out:
# <title>Booking.com: Hotels in Tokyo. Book your hotel now!</title>
# 0
# APA Hotel Asakusa Tawaramachi Ekimae done
# Best Apartment in Shinjuku done
# MARUTOMO HOTEL AKIHABARA done
# Shinagawa Prince Hotel East Tower done
# Hotel Resol Akihabara done
# The Royal Park Canvas - Ginza 8 done
# THE BLOSSOM HIBIYA done
# Sakura Cross Hotel Akihabara done
# APA Hotel Pride Kokkaigijidomae - National Diet Bldg. done
# LY Inn Tokyo Honjo done
# Mustard Hotel Asakusa 2 done
# Mitsui Garden Hotel Ginza-gochome done
# Shibuya Star done
# Sadou Hostel Tokyo Ueno done
# 3 BR House Harajuku SS #002 done
# <title>Booking.com: Hotels in Tokyo. Book your hotel now!</title>
# 1
# Apartment Sun Bright Shinagawa done
# an/other TOKYO done
# Henn na Hotel Tokyo Akasaka done
# Henn na Hotel Tokyo Hamamatsucho done
# Henn na Hotel Tokyo Asakusabashi done
# Rhodes Kagurazaka Hotel done
# nine hours Akasaka done
# Dormy Inn Korakuen done
# Mustard Hotel Shibuya done
# NY Stage 新宿 done
# Shinagawa Prince Hotel N Tower done
# Candeo Hotels Ueno Park done
# The Millennials Shibuya done
# HOTEL GRANHILL (Adult Only) done
# Turn Table Hostel done
# <title>Booking.com: Hotels in Tokyo. Book your hotel now!</title>
# 2
# Comfort Suites Tokyo Bay done
# ICI HOTEL Akasaka by RELIEF done
# Smart Stay Tokyo in Shinjuku done
# 三叶民宿 done
# Hotel Tsukigime Club Asakusa Azumabashi done
# LY Inn Tokyo Bakurocho done
# Sotetsu Fresa Inn Tokyo Kinshicho done
# Green Hotel done
# First Cabin Nihonbashi Suitengu done
# Guanjing Apartment done
# MIMARU Tokyo Hatchobori done
# Grand Residence Nakameguro done
# Grids Tokyo Akihabara Hotel&Hostel done
# Hotel MONday Toyosu done
# Hotel Oriental Express Tokyo Ginza done
# <title>Booking.com: Hotels in Kyoto. Book your hotel now!</title>
# 0
# Hotel Keihan Kyoto Grande done
# Gion Komachi done
# GRAND JAPANING HOTEL Kyoto Station KOMEYA done
# GRAND JAPANING HOTEL Gojo NAGINATAGIRI done
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1639                         raise SysCallError(errno, errorcode.get(errno))
# -> 1640                 raise SysCallError(-1, "Unexpected EOF")
#    1641             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     593             if is_new_proxy_conn:
# --> 594                 self._prepare_proxy(conn)
#     595
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     804         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 805         conn.connect()
#     806
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     461             except OpenSSL.SSL.Error as e:
# --> 462                 raise ssl.SSLError('bad handshake: %r' % e)
#     463             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /hotel/jp/gesutohausuyue-chen-yuan.html?label=gen173nr-1FCAEoggI46AdIM1gEaIkCiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuALer57nBcACAQ&sid=7dd7e0489d212e83f4989d28cce6cc49&dest_id=-235402&dest_type=city&hapos=5&hpos=5&sr_order=popularity&srepoch=1558681572&srpvid=c71631f26a580131&ucfs=1&from=searchresults;highlight_room= (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-14-695c83b20f06> in <module>
#      85                 url1 = str1 + str2
#      86                 #print (url1)
# ---> 87                 response =requests.get(url1)
#      88                 #print(response.status_code)
#      89                 page = response.text
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /hotel/jp/gesutohausuyue-chen-yuan.html?label=gen173nr-1FCAEoggI46AdIM1gEaIkCiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuALer57nBcACAQ&sid=7dd7e0489d212e83f4989d28cce6cc49&dest_id=-235402&dest_type=city&hapos=5&hpos=5&sr_order=popularity&srepoch=1558681572&srpvid=c71631f26a580131&ucfs=1&from=searchresults;highlight_room= (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
